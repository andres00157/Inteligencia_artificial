# %% [markdown]
# <a href="https://colab.research.google.com/github/andres00157/Inteligencia_artificial/blob/main/Taller_probabilidad_semana_2-3/Taller_semana_2_probabilidad_Andres_Barreto_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller en clase #1   Hecho por Andres Barreto
# Generando numeros aleatorios en python.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=100000
m=300 ## se bajo el numero para que se aprecie correctamente los histogramas
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750560000003

# %% [markdown]
# ### Primer punto experimento binomial

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n,p = 10, 0.5
from scipy.stats import binom

mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')

numpy.random.seed(seed=2**32 - 1)
#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

r = binom.rvs(n,p, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomialmente con p="+str(p)+" y n="+str(n))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomielmente ordenados con p="+str(p)+ " y n="+str(n))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p)+" y n="+str(n))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial con p="+str(p)+" y n="+str(n)+" son u=" +str(mean)+" var="+str(var))
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con p=",p," y n=",n,"son u_est=",avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con p=0.5 y n=10 son u=5.0 var=2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con p= 0.5  y n= 10 son u_est= 4.99695 var_est= 2.4928206975000005

# %% [markdown]
# ### Primer punto experimento distribucion geometrica

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3
from scipy.stats import geom

mean, var, skew, kurt = geom.stats(p, moments='mvsk')

numpy.random.seed(seed=2**32 - 1)
#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

r = geom.rvs(p, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la geometricamente con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la geometricamente con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la geometricamente con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la geometricamente con p= 0.3 son u_est= 3.32064 var_est= 7.647549990399999

# %% [markdown]
# ### Primer punto experimento distribucion Poisson

# %%
# Poisson con cierto Lamnda L
L = 5

from scipy.stats import poisson

mean, var, skew, kurt = poisson.stats(L, moments='mvsk')

numpy.random.seed(seed=2**32 - 1)
#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

r = poisson.rvs(L, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos poisson con L="+str(L))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos poisson ordenados con L="+str(L))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos poisson con p="+str(p))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la poisson con L=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la poisson con L=",L,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la poisson con L= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para la poisson con L= 5 son u_est= 4.99164 var_est= 4.9669701104

# %% [markdown]
# ### Primer punto experimento distribucion Binomial negativa

# %%
#Binomial negativa con parametro p después de r fallos
r_binom,p = 5,0.5

from scipy.stats import nbinom

mean, var, skew, kurt = nbinom.stats(r_binom, p, moments='mvsk')

numpy.random.seed(seed=2**32 - 1)
#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

r = nbinom.rvs(r_binom,p, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial negativa con p="+str(p)+" y r="+str(r_binom))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial negativa con p="+str(p)+" y r="+str(r_binom))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial negativa con p="+str(p)+" y r="+str(r_binom))
plt.show()
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial negativa con p="+str(p)+" y r="+str(r_binom),"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa con p="+str(p)+" y r="+str(r_binom),"son u_est=" ,avg,"var_est=",varest)
# Out:
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial negativa con p=0.5 y r=5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa con p=0.5 y r=5 son u_est= 4.99537 var_est= 10.030848563100001

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
import scipy
N=1000000  ## se cambio el N a 1000000 para poder observar de una mejor manera el histograma 
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %% [markdown]
# ### Segundo punto experimento distribucion Normal

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.999291628266701 var_est= 0.2497974600746034

# %% [markdown]
# ### Segundo punto experimento distribucion uniforme

# %%
# Uniforme entre 0 y 255
a = 0
b = 255
mean, var, skew, kurt = scipy.stats.uniform.stats(moments='mvsk',loc=a,scale=b)
r = scipy.stats.uniform.rvs (loc=a,scale=b, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniformemente con a= "+str(a)+" y b="+str(b))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniformemente ordenados con a= "+str(a)+" y b="+str(b))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos uniformemente con a= "+str(a)+" y b="+str(b))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la uniformemente son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la uniformemente son u= 127.5 var= 5418.75
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 127.48323592803976 var_est= 5420.975275763698

# %% [markdown]
# ### Segundo punto experimento distribucion exponencial

# %%
# Exponencial con Lamnda L
L=0.3

mean, var, skew, kurt = scipy.stats.expon.stats(L,moments='mvsk')
r = scipy.stats.expon.rvs (L, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencial con L="+ str(L))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencial ordenados con L="+ str(L))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencial con L="+ str(L))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la exponencial son u= 1.3 var= 1.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.2982905614311828 var_est= 0.9970809117186619

# %% [markdown]
# ### Segundo punto experimento distribucion chi cuadrado

# %%
#Chi cuadrada con K grados de libertad
K=3.0

mean, var, skew, kurt = scipy.stats.chi2.stats(K,moments='mvsk')
r = scipy.stats.chi2.rvs (K, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos chi cuadrado con K="+ str(K))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos chi cuadrado ordenados con K="+ str(K))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos chi cuadrado con K="+ str(K))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la chi cuadrado son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la chi cuadrado son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 3.000669207404234 var_est= 6.015754118527393

# %% [markdown]
# ### Segundo punto experimento distribucion Gamma

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43


mean, var, skew, kurt = scipy.stats.gamma.stats(a = k,scale = t,moments='mvsk')
r = scipy.stats.gamma.rvs (a = k,scale = t, size=N)

plt.plot(r)
plt.title(str(N)+" puntos distribuidos gamma con k="+ str(k)+" y t="+str(t))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos gamma ordenados con k="+ str(k)+" y t="+str(t))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos gamma con k="+ str(k)+" y t="+str(t))
plt.show()
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Los valores teoricos de la media y varianza para la gamma son u= 1.0922 var= 0.469646
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.0930165380016463 var_est= 0.469317484677709
